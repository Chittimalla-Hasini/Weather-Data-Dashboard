# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("weather.csv.xlsx")
df.head
# Out:
# <bound method NDFrame.head of            date  precipitatio  temp_max  temp_min  wind  weather
# 0    2012-01-01           0.0      12.8       5.0   4.7  drizzle
# 1    2012-01-02          10.9      10.6       2.8   4.5     rain
# 2    2012-01-03           0.8      11.7       7.2   2.3     rain
# 3    2012-01-04          20.3      12.2       5.6   4.7     rain
# 4    2012-01-05           1.3       8.9       2.8   6.1     rain
# ...         ...           ...       ...       ...   ...      ...
# 1456 2015-12-27           8.6       4.4       1.7   2.9     rain
# 1457 2015-12-28           1.5       5.0       1.7   1.3     rain
# 1458 2015-12-29           0.0       7.2       0.6   2.6      fog
# 1459 2015-12-30           0.0       5.6      -1.0   3.4      sun
# 1460 2015-12-31           0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]>

# %%
df['date'] = pd.to_datetime(df['date'], format='%d-%m-%Y')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1461 non-null   datetime64[ns]
#  1   precipitatio  1461 non-null   float64
#  2   temp_max      1461 non-null   float64
#  3   temp_min      1461 non-null   float64
#  4   wind          1461 non-null   float64
#  5   weather       1461 non-null   object
# dtypes: datetime64[ns](1), float64(4), object(1)
# memory usage: 68.6+ KB

# %%
df.describe()
df['weather'].value_counts()
# Out:
# weather
# rain       641
# sun        640
# fog        101
# drizzle     53
# snow        26
# Name: count, dtype: int64

# %%
df['month'] = df['date'].dt.month
df.head()
# Out:
#         date  precipitatio  temp_max  temp_min  wind  weather  month
# 0 2012-01-01           0.0      12.8       5.0   4.7  drizzle      1
# 1 2012-01-02          10.9      10.6       2.8   4.5     rain      1
# 2 2012-01-03           0.8      11.7       7.2   2.3     rain      1
# 3 2012-01-04          20.3      12.2       5.6   4.7     rain      1
# 4 2012-01-05           1.3       8.9       2.8   6.1     rain      1

# %%
plt.figure(figsize=(10,5))
plt.plot(df['date'], df['temp_max'], label='Max Temp')
plt.plot(df['date'], df['temp_min'], label='Min Temp')

plt.legend()
plt.title("Temperature Trend")
plt.show()

# %%
plt.plot(df['date'], df['precipitatio'])
plt.title("Rainfall Trend")
plt.show()

# %%
df['weather'].value_counts().plot(kind='bar')
plt.title("Weather Distribution")
plt.show()

# %%
df['temp_max'].max()
# Out:
# 35.6

# %%
df['temp_min'].min()
# Out:
# -7.1

# %%
df['temp_max'].mean()
# Out:
# np.float64(16.43908281998631)

# %%
df['temp_max'].describe()
# Out:
# count    1461.000000
# mean       16.439083
# std         7.349758
# min        -1.600000
# 25%        10.600000
# 50%        15.600000
# 75%        22.200000
# max        35.600000
# Name: temp_max, dtype: float64
